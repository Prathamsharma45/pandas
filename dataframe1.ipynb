# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv('StudentsPerformance.csv')

# %%
data1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data1.value_counts('race/ethnicity')
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
data1.rename(columns={'race/ethnicity':'group'},inplace=True)
data1
# Out:
#      gender    group parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
print(data1['gender'].unique())
print(data1['group'].unique())
print(data1['parental level of education'].unique())
# Out:
# ['female' 'male']
# ['group B' 'group C' 'group A' 'group D' 'group E']
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']

# %%
group=data1.groupby('group')
print(group)

# %%
type(group)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
for group,data in group:
    print(group)
    print(data)
# Out:
# group A
#      gender    group parental level of education         lunch  \
# 3      male  group A          associate's degree  free/reduced
# 13     male  group A                some college      standard
# 14   female  group A             master's degree      standard
# 25     male  group A             master's degree  free/reduced
# 46   female  group A          associate's degree      standard
# ..      ...      ...                         ...           ...
# 974  female  group A                some college      standard
# 983  female  group A                some college      standard
# 985    male  group A                 high school      standard
# 988  female  group A            some high school  free/reduced
# 994    male  group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
parentallevelofeducation =data1.groupby('parental level of education')
print(parentallevelofeducation)

# %%
type(parentallevelofeducation)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
for parentallevelofeducation,data in parentallevelofeducation:
    print(parentallevelofeducation)
    print(data)
# Out:
# associate's degree
#      gender    group parental level of education         lunch  \
# 3      male  group A          associate's degree  free/reduced
# 5    female  group B          associate's degree      standard
# 10     male  group C          associate's degree      standard
# 11     male  group D          associate's degree      standard
# 19   female  group C          associate's degree  free/reduced
# ..      ...      ...                         ...           ...
# 968  female  group E          associate's degree      standard
# 977    male  group C          associate's degree      standard
# 979  female  group C          associate's degree      standard
# 986  female  group C          associate's degree      standard
# 992  female  group D          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
group.sum(numeric_only=True)
# Out:
#          math score  reading score  writing score
# group
# group A        5485           5756           5578
# group B       12056          12797          12464
# group C       20564          22044          21637
# group D       17649          18348          18378
# group E       10335          10224           9997

# %%
group.mean(numeric_only=True)
# Out:
#          math score  reading score  writing score
# group
# group A   61.629213      64.674157      62.674157
# group B   63.452632      67.352632      65.600000
# group C   64.463950      69.103448      67.827586
# group D   67.362595      70.030534      70.145038
# group E   73.821429      73.028571      71.407143

# %%
group.max(numeric_only=True)
# Out:
#          math score  reading score  writing score
# group
# group A         100            100             97
# group B          97             97             96
# group C          98            100            100
# group D         100            100            100
# group E         100            100            100

# %%
group.count()
# Out:
#          gender  parental level of education  lunch  test preparation course  \
# group
# group A      89                           89     89                       89
# group B     190                          190    190                      190
# group C     319                          319    319                      319
# group D     262                          262    262                      262
# group E     140                          140    140                      140
#
#          math score  reading score  writing score
# group
# group A          89             89             89
# group B         190            190            190
# group C         319            319            319
# group D         262            262            262
# group E         140            140            140

# %%
print(group['math score'].sum().sort_values().tail(1))
# Out:
# group
# group C    20564
# Name: math score, dtype: int64

# %%
print(group['writing score'].mean().sort_values().tail(1))
# Out:
# group
# group E    71.407143
# Name: writing score, dtype: float64

# %%
print(parentallevelofeducation['math score'].max().sort_values())
# Out:
# parental level of education
# master's degree        95
# some high school       97
# high school            99
# bachelor's degree     100
# associate's degree    100
# some college          100
# Name: math score, dtype: int64

# %%
print(parentallevelofeducation['math score'].max().sort_values().tail(3))
# Out:
# parental level of education
# bachelor's degree     100
# associate's degree    100
# some college          100
# Name: math score, dtype: int64

# %%
data1.groupby('parental level of education').groups
# Out:
# {'associate's degree': [3, 5, 10, 11, 19, 35, 36, 38, 39, 40, 41, 42, 44, 45, 46, 48, 51, 56, 57, 62, 63, 68, 69, 72, 75, 80, 83, 87, 93, 95, 102, 107, 108, 110, 112, 121, 138, 147, 149, 152, 158, 159, 160, 173, 177, 183, 185, 190, 195, 200, 202, 203, 213, 216, 221, 224, 231, 235, 239, 245, 246, 256, 257, 268, 272, 285, 286, 290, 295, 297, 299, 302, 303, 304, 308, 310, 313, 317, 319, 328, 331, 332, 333, 337, 343, 349, 353, 356, 375, 380, 381, 387, 393, 397, 406, 407, 409, 412, 417, 420, ...], 'bachelor's degree': [0, 24, 27, 60, 77, 90, 99, 101, 114, 116, 117, 120, 129, 134, 135, 148, 151, 153, 165, 174, 189, 199, 206, 232, 234, 236, 241, 266, 270, 275, 279, 282, 288, 293, 311, 312, 314, 318, 334, 347, 350, 355, 365, 367, 374, 379, 386, 414, 416, 426, 455, 456, 458, 460, 464, 475, 476, 493, 507, 509, 522, 528, 535, 538, 551, 562, 564, 566, 569, 571, 582, 587, 592, 594, 595, 612, 616, 617, 621, 624, 632, 645, 667, 692, 697, 700, 702, 705, 740, 748, 757, 771, 773, 784, 809, 816, 817, 8
# ...

# %%
data1.iloc[99]
# Out:
# gender                                    female
# group                                    group D
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                    65
# reading score                                 67
# writing score                                 62
# Name: 99, dtype: object

# %%
data1.groupby('parental level of education').ngroups
# Out:
# 6

# %%
data1.groupby('parental level of education').size()
# Out:
# parental level of education
# associate's degree    222
# bachelor's degree     118
# high school           196
# master's degree        59
# some college          226
# some high school      179
# dtype: int64

# %%
group.indices
# Out:
# {'group A': array([  3,  13,  14,  25,  46,  61,  62,  72,  77,  82,  88, 112, 129,
#         143, 150, 151, 170, 228, 250, 296, 300, 305, 327, 356, 365, 368,
#         378, 379, 384, 395, 401, 402, 423, 428, 433, 442, 444, 464, 467,
#         468, 483, 489, 490, 506, 511, 539, 546, 571, 575, 576, 586, 589,
#         591, 597, 614, 623, 635, 651, 653, 688, 697, 702, 705, 731, 741,
#         769, 778, 805, 810, 811, 816, 820, 830, 832, 837, 851, 892, 902,
#         911, 936, 943, 960, 966, 972, 974, 983, 985, 988, 994]),
#  'group B': array([  0,   2,   5,   6,   7,   9,  12,  17,  21,  26,  31,  39,  42,
#          43,  45,  65,  68,  75,  80,  81,  94,  96, 100, 103, 108, 109,
#         116, 121, 125, 126, 136, 146, 152, 157, 158, 160, 162, 167, 168,
#         176, 178, 188, 192, 198, 199, 203, 208, 209, 215, 218, 219, 221,
#         224, 232, 238, 247, 248, 252, 258, 274, 279, 284, 285, 287, 288,
#         295, 303, 308, 310, 311, 318, 329, 333, 335, 338, 342, 346, 350,
# ...

# %%
group.agg(
     {
        'math score ':'mean',
        'reading score':'max',
        'writing':'sum',
     }
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 group.agg(
#       2      {
#       3         'math score ':'mean',
#       4         'reading score':'max',
#       5         'writing':'sum',
#       6      }
#       7 )
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
# ...

# %%
group.agg(
    {
        'math score':'mean',
        'reading score':'std',
    }
)
