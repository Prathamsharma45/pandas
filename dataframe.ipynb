# %%
import pandas as pd
import numpy as np

# %%
datasample=[[50,6,0],[78,9,5],[55,55,78],[6,8,9]]
data1=pd.DataFrame(datasample,columns=['python','c++','java'])
data1
# Out:
#    python  c++  java
# 0      50    6     0
# 1      78    9     5
# 2      55   55    78
# 3       6    8     9

# %%
#using dict
data_dict={
    'col1':['name1','name2','name3','name4','name5','name6'],
    'col2':[100,90,120,80,0,0],
    'col3':[80,70,100,50,0,0],
    'col4':[10,7,14,2,0,0]
}
students=pd.DataFrame(data_dict)
students.set_index('col1',inplace=True)       #for us eof column data has been
students
# Out:
#        col2  col3  col4
# col1
# name1   100    80    10
# name2    90    70     7
# name3   120   100    14
# name4    80    50     2
# name5     0     0     0
# name6     0     0     0

# %%
titanic=pd.read_csv("Titanic Dataset.csv")
print(titanic)
print()
print(titanic.shape)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
weather=pd.read_csv("austin_weather.csv")
print(weather)
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
titanic=pd.read_csv("Titanic Dataset.csv")
print(titanic)
print(titanic.shape)
print(titanic.dtypes)
print(titanic.index)
print(titanic.columns)
print(type(titanic.values))
print(titanic.head(5))
print(titanic.tail(5))
print(titanic.sample())
print(titanic.info())
print(titanic.describe())
print(titanic.isnull().sum())
print(titanic.duplicated().sum)
print(titanic.duplicated())
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
weather=pd.read_csv("austin_weather.csv")
print(weather)

print(weather.shape)
print(weather.dtypes)
print(weather.index)
print(weather.columns)
print(type(weather.values))
print(weather.head(5))
print(weather.tail(5))
print(weather.sample())
print(weather.info())
print(weather.describe())
print(weather.isnull().sum())
print(weather.duplicated().sum)
print(weather.duplicated())
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
#pandas dataframe funcation 
print(students)
print(students.duplicated().sum())
print(students.duplicated())
# Out:
#        col2  col3  col4
# col1
# name1   100    80    10
# name2    90    70     7
# name3   120   100    14
# name4    80    50     2
# name5     0     0     0
# name6     0     0     0
# 1
# col1
# name1    False
# name2    False
# name3    False
# name4    False
# name5    False
# name6     True
# dtype: bool

# %%
x=students.rename(columns={'col2':'python','col3':'c++'},inplace=True)
print(x)
# Out:
# None

# %%
students.sum(axis=0)#in pandas axis =0 it axis the columns
# Out:
# python    390
# c++       300
# col4       33
# dtype: int64

# %%
students.sum(axis=1)#it is used for row
# Out:
# col1
# name1    190
# name2    167
# name3    234
# name4    132
# name5      0
# name6      0
# dtype: int64

# %%
students.mean(axis=1)
# Out:
# col1
# name1    63.333333
# name2    55.666667
# name3    78.000000
# name4    44.000000
# name5     0.000000
# name6     0.000000
# dtype: float64

# %%
students.var()
# Out:
# python    2710.0
# c++       1760.0
# col4        33.5
# dtype: float64

# %%
students.std()
# Out:
# python    52.057660
# c++       41.952354
# col4       5.787918
# dtype: float64

# %%
weather=pd.read_csv("austin_weather.csv")
print(weather.columns)
# Out:
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
weather[['Date','TempHighF']]
# Out:
#             Date  TempHighF
# 0     2013-12-21         74
# 1     2013-12-22         56
# 2     2013-12-23         58
# 3     2013-12-24         61
# 4     2013-12-25         58
# ...          ...        ...
# 1314  2017-07-27        103
# 1315  2017-07-28        105
# 1316  2017-07-29        107
# 1317  2017-07-30        106
# 1318  2017-07-31         99
#
# [1319 rows x 2 columns]

# %%
titanic=pd.read_csv("Titanic Dataset.csv")
print(titanic.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic[['PassengerId','Pclass','Parch']]
# Out:
#      PassengerId  Pclass  Parch
# 0            892       3      0
# 1            893       3      0
# 2            894       2      0
# 3            895       3      0
# 4            896       3      1
# ..           ...     ...    ...
# 413         1305       3      0
# 414         1306       1      0
# 415         1307       3      0
# 416         1308       3      0
# 417         1309       3      1
#
# [418 rows x 3 columns]

# %%
titanic.iloc[4]#it is iloc funcation use for access row
# Out:
# PassengerId                                             896
# Survived                                                  1
# Pclass                                                    3
# Name           Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# Sex                                                  female
# Age                                                    22.0
# SibSp                                                     1
# Parch                                                     1
# Ticket                                              3101298
# Fare                                                12.2875
# Cabin                                                   NaN
# Embarked                                                  S
# Name: 4, dtype: object

# %%
titanic.iloc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.iloc[[0,5,6,7,8,9,5]]
# Out:
#    PassengerId  Survived  Pclass                                       Name  \
# 0          892         0       3                           Kelly, Mr. James
# 5          897         0       3                 Svensson, Mr. Johan Cervin
# 6          898         1       3                       Connolly, Miss. Kate
# 7          899         0       2               Caldwell, Mr. Albert Francis
# 8          900         1       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9          901         0       3                    Davies, Mr. John Samuel
# 5          897         0       3                 Svensson, Mr. Johan Cervin
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  34.5      0      0     330911   7.8292   NaN        Q
# 5    male  14.0      0      0       7538   9.2250   NaN        S
# 6  female  30.0      0      0     330972   7.6292   NaN        Q
# 7    male  26.0      1      1     248738  29.0000   NaN        S
# ...

# %%
students.loc['name1']
# Out:
# python    100
# c++        80
# col4       10
# Name: name1, dtype: int64

# %%
students.loc['name1':'name5':2]
# Out:
#        python  c++  col4
# col1
# name1     100   80    10
# name3     120  100    14
# name5       0    0     0

# %%
students.loc[['name1','name3','name2']]
# Out:
#        python  c++  col4
# col1
# name1     100   80    10
# name3     120  100    14
# name2      90   70     7

# %%
titanic.iloc[0:3,0:7]
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp
# 0  34.5      0
# 1  47.0      1
# 2  62.0      0

# %%
titanic.loc[0:9:2,"PassengerId":"Age"]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 2          894         0       2
# 4          896         1       3
# 6          898         1       3
# 8          900         1       3
#
#                                            Name     Sex   Age
# 0                              Kelly, Mr. James    male  34.5
# 2                     Myles, Mr. Thomas Francis    male  62.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 6                          Connolly, Miss. Kate  female  30.0
# 8     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
titanic['Country']='India'
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 274         1166         0       3          Saade, Mr. Jean Nassr    male
# 156         1048         1       1              Bird, Miss. Ellen  female
# 390         1282         0       1     Payne, Mr. Vivian Ponsonby    male
# 155         1047         0       3           Duquemin, Mr. Joseph    male
# 334         1226         0       3                  Cor, Mr. Ivan    male
# 337         1229         0       3              Elias, Mr. Joseph    male
# 52           944         1       2  Hocking, Miss. Ellen Nellie""  female
# 133         1025         0       3          Thomas, Mr. Charles P    male
# 99           991         0       3   Nancarrow, Mr. William Henry    male
# 313         1205         1       3            Carr, Miss. Jeannie  female
#
#       Age  SibSp  Parch         Ticket      Fare Cabin Embarked Country
# 274   NaN      0      0           2676    7.2250   NaN        C   India
# ...

# %%
titanic['First Name']=titanic['Name'].str.split(',').apply(lambda x:x[0])
titanic['First Name' ]
# Out:
# 0              Kelly
# 1             Wilkes
# 2              Myles
# 3               Wirz
# 4           Hirvonen
#            ...
# 413          Spector
# 414    Oliva y Ocana
# 415          Saether
# 416             Ware
# 417            Peter
# Name: First Name, Length: 418, dtype: object

# %%
name='Manoj kumar sharma'
y=" ".join(name.split () [0:2]) #join funcation
print(y)
# Out:
# Manoj kumar

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic['PassengerId']=titanic['PassengerId'].astype('int32')      #Astype  funcation in dataframe
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic['PassengerId'].dtype
# Out:
# dtype('int32')

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
# ...

# %%
weather['Events']=weather['Events'].astype('category')
weather.info()
weather['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
# ...

# %%
titanic['PassengerId']=titanic['PassengerId'].astype('category')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    category
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
#  12  Country      418 non-null    object
# dtypes: category(1), float64(2), int64(4), object(6)
# memory usage: 53.9+ KB

# %%
#value_count funcation
students.value_counts()
# Out:
# python  c++  col4
# 0       0    0       2
# 80      50   2       1
# 90      70   7       1
# 100     80   10      1
# 120     100  14      1
# Name: count, dtype: int64

# %%
titanic['Sex'].value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
((titanic['Age']>=40)&(titanic['Sex']=='male')).value_counts()
# Out:
# False    366
# True      52
# Name: count, dtype: int64

# %%
((titanic['SibSp']==0)&(titanic['Parch']==0)).value_counts()
# Out:
# True     253
# False    165
# Name: count, dtype: int64

# %%
((titanic['Age']>50)&(titanic['Sex']=='male')|(titanic['Age']>40)&(titanic['Sex']=='female')).value_counts()
# Out:
# False    372
# True      46
# Name: count, dtype: int64

# %%
#Sort values funcation

# %%
titanic.sort_values('PassengerId',ascending=False)
# Out:
#     PassengerId  Survived  Pclass  \
# 417        1309         0       3
# 416        1308         0       3
# 415        1307         0       3
# 414        1306         1       1
# 413        1305         0       3
# ..          ...       ...     ...
# 4           896         1       3
# 3           895         0       3
# 2           894         0       2
# 1           893         1       3
# 0           892         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 417                      Peter, Master. Michael J    male   NaN      1      1
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# ..                                            ...     ...   ...    ...    ...
# ...

# %%
titanic.sort_values(['Pclass','Name'],ascending=[True,False])
# Out:
#     PassengerId  Survived  Pclass  \
# 371        1263         1       1
# 23          915         0       1
# 231        1123         1       1
# 218        1110         1       1
# 407        1299         0       1
# ..          ...       ...     ...
# 8           900         1       3
# 251        1143         0       3
# 57          949         0       3
# 345        1237         1       3
# 392        1284         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 371                     Wilson, Miss. Helen Alice  female  31.0      0      0
# 23                Williams, Mr. Richard Norris II    male  21.0      0      1
# 231                      Willard, Miss. Constance  female  21.0      0      0
# 218  Widener, Mrs. George Dunton (Eleanor Elkins)  female  50.0      1      1
# 407                    Widener, Mr. George Dunton    male  50.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...

# %%
titanic.sort_index(ascending=False)
# Out:
#     PassengerId  Survived  Pclass  \
# 417        1309         0       3
# 416        1308         0       3
# 415        1307         0       3
# 414        1306         1       1
# 413        1305         0       3
# ..          ...       ...     ...
# 4           896         1       3
# 3           895         0       3
# 2           894         0       2
# 1           893         1       3
# 0           892         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 417                      Peter, Master. Michael J    male   NaN      1      1
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# ..                                            ...     ...   ...    ...    ...
# ...

# %%
titanic.set_index('PassengerId',inplace=True)
titanic.head()
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#                 Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked  \
# PassengerId
# 892            male  34.5      0      0   330911   7.8292   NaN        Q
# 893          female  47.0      1      0   363272   7.0000   NaN        S
# 894            male  62.0      0      0   240276   9.6875   NaN        Q
# 895            male  27.0      0      0   315154   8.6625   NaN        S
# 896          female  22.0      1      1  3101298  12.2875   NaN        S
#
#             Country
# PassengerId
# ...

# %%
titanic.reset_index(inplace=True)

# %%
marks={
    'maths':67,'sst':89,'physics':78,'hndi':89,'English':57

}
marks_series=pd.Series(marks)
marks_series
# Out:
# maths      67
# sst        89
# physics    78
# hndi       89
# English    57
# dtype: int64

# %%
marks_series.reset_index(inplace=False)
# Out:
#      index   0
# 0    maths  67
# 1      sst  89
# 2  physics  78
# 3     hndi  89
# 4  English  57

# %%
titanic['PassengerId']=titanic['PassengerId'].fillna('------------------',inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12484\795887923.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['PassengerId']=titanic['PassengerId'].fillna('------------------',inplace=True)

# %%
titanic = pd.read_csv("Titanic Dataset.csv")

# Select rows where Fare > 100 and Age < 30, then count them
result = ((titanic['Fare'] > 100) & (titanic['Age'] < 30)).value_counts()
print(result)

# Display the 'Name' column
print(titanic['Name'])

# Count of males with Age >= 40
print(((titanic['Age'] >= 40) & (titanic['Sex'] == 'male')).value_counts())
# Out:
# False    411
# True       7
# Name: count, dtype: int64
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object
# False    366
# True      52
# Name: count, dtype: int64

# %%
import pandas as pd
df = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")
print(df)

team = df.groupby('Team')
print(team.first()) # Let's print the first entries in all the groups formed.
#group by funcation using to group
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...
