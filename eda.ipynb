# %%
import seaborn as sns 
import pandas as pd

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# # it is mainly usse in the information about the dataset
# # data gathering
# # data anallysis
# # data cleaning
# # data visualization
# # data modeling
# # data deployment
# #
# # there are minly five types of fearture in data set
# # 1. numerical feature
# # 2. categorical feature
# # 3. ordinal feature
# # 4. text feature
# # 5. datetime feature

# %%
df['tip']=df['tip'].astype(dtype='float32')
df['size']=df['size'].astype(dtype='int32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float32
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int32
# dtypes: category(4), float32(1), float64(1), int32(1)
# memory usage: 5.5 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.isnull().sum()# there should not be
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df[(df['tip']>2)&(df['tip']<3)]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 31        18.35  2.50    Male     No   Sat  Dinner     4
# 33        20.69  2.45  Female     No   Sat  Dinner     4
# 38        18.69  2.31    Male     No   Sat  Dinner     3
# 40        16.04  2.24    Male     No   Sat  Dinner     3
# 41        17.46  2.54    Male     No   Sun  Dinner     2
# 48        28.55  2.05    Male     No   Sun  Dinner     3
# 50        12.54  2.50    Male     No   Sun  Dinner     2
# 51        10.29  2.60  Female     No   Sun  Dinner     2
# 64        17.59  2.64    Male     No   Sat  Dinner     3
# 66        16.45  2.47  Female     No   Sat  Dinner     2
# 68        20.23  2.01    Male     No   Sat  Dinner     2
# 69        15.01  2.09    Male    Yes   Sat  Dinner     2
# ...

# %%
df[(df['tip']>2)&(df['tip']<3)].shape# this is how we can filter the data
# Out:
# (45, 7)

# %%
(df[(df['tip']>2)&(df['tip']<3)].columns)
df[(df['tip']>2)&(df['tip']<3)].index
df[(df['tip']>2)&(df['tip']<3)].dtypes
len(df[(df['tip']>2)&(df['tip']<3)])
tuple(df[(df['tip']>2)&(df['tip']<3)])
# Out:
# ('total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size')
